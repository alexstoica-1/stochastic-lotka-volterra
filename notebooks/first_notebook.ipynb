# %% [markdown]
# <h1 style="text-align:center;">Stochastic Lotka–Volterra</h1>
# <h3 style="text-align:center;">Course: Stochastic Processes and Simulations in Natural Sciences (30561)</h3>
# <h5 style="text-align:center;">Stoica Alexandru()   Dontu Catalin()   Antonescu Victor-Gabriel()</h3>
#
# ### Table of Contents:
# 1. Introduction
# 2.

# %% [markdown]
# ### Introduction
#
# Stochastic Lotka Voltera blah blah blah
